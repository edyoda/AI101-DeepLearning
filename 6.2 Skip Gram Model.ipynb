# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
# (Credits : Thushan Ganegedara's implementation)
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:100])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst', 'the', 'term', 'is', 'still', 'used', 'in', 'a', 'pejorative', 'way', 'to', 'describe', 'any', 'act', 'that', 'used', 'violent', 'means', 'to', 'destroy', 'the', 'organization', 'of', 'society', 'it', 'has', 'also', 'been', 'taken', 'up', 'as', 'a', 'positive', 'label', 'by', 'self', 'defined', 'anarchists', 'the', 'word', 'anarchism', 'is', 'derived', 'from', 'the', 'greek', 'without', 'archons', 'ruler', 'chief', 'king', 'anarchism', 'as', 'a', 'political', 'philosophy', 'is', 'the', 'belief', 'that', 'rulers', 'are', 'unnecessary', 'and', 'should', 'be', 'abolished', 'although', 'there', 'are', 'differing']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
np.random.seed(123)

def sub_sampling(int_words, threshold):
    word_counter = Counter(int_words)
    total_count = len(int_words)
    freq= {word: count/total_count for word,count in word_counter.items()}
    p_drop ={word:(1-np.sqrt(threshold/ freq[word])) for word in word_counter}
    trained_words = [word for word in int_words if p_drop[word]<np.random.random()]
    return trained_words

train_words = sub_sampling(int_words, threshold= 1e-5)

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name = 'inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200              # Number of embedding features 
with train_graph.as_default():
    
    # embedding = tf.Variable(tf.truncated_normal([n_vocab, n_embedding], stddev=0.1))    #embedding weight matrix
    
    embedding = tf.Variable(tf.random_uniform([n_vocab,n_embedding],-1, 1))   
    embed = tf.nn.embedding_lookup(embedding, inputs)     #tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab, n_embedding], stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)
# Out:
# WARNING:tensorflow:From /home/jaley/anaconda3/envs/tensorflow-cpu/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:1124: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
import random

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    
    valid_size = 16               # Random set of words to evaluate similarity on.
    valid_window = 100
    
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-16-e316d670476b>:16: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6746 0.2851 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6534 0.2805 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4875 0.2881 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6245 0.2735 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4781 0.2739 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5559 0.2741 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5659 0.2783 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5548 0.2807 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4705 0.2805 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4300 0.2800 sec/batch
# Nearest to however: heart, affluent, cafeteria, ojibwa, memory, resistors, leads, gradient,
# Nearest to two: redfield, bodleian, upsets, gallons, paid, gammu, vesque, franconia,
# Nearest to some: nus, alcoholic, sectioned, transoceanic, eller, leach, presents, morning,
# Nearest to it: defaults, partido, cleanse, paid, exposed, grasping, promotion, wove,
# Nearest to to: ltte, underdeveloped, stays, gouverneur, brush, entrails, afips, farmhouse,
# Nearest to more: shilling, diet, quiescent, infantryman, harry, anybody, charts, buccaneer,
# Nearest to nine: u, collin, elmira, endeavor, encyclopedists, herb, breaded, verification,
# Nearest to not: aisles, pterosaurs, atrocities, rang, engler, ubi, bengals, mukti,
# Nearest to shows: chinook, talvela, hammerhead, passively, drainage, approves, heliocentric, calendars,
# Nearest to primarily: abiotic, scratch, barbuda, conditionals, fragments, predominantly, charlestown, nephite,
# Nearest to troops: fatalities, soundly, trainspotting, facetiously, campy, epsilon, smarta, metaphilosophy,
# Nearest to something: gordian, hour, subscripts, lpu, crean, starting, vietnamese, cartography,
# Nearest to freedom: footwear, grade, hamburger, traumatic, tiles, radclyffe, essene, utterances,
# Nearest to centre: dowland, catnip, distro, obtuse, gpo, metamorphosis, alm, spook,
# Nearest to versions: ahmet, tailored, durum, eszterh, ningbo, torvalds, staunchly, hypothesizing,
# Nearest to operations: humps, motocross, technik, larsen, sheng, subtlety, gehrig, directory,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4768 0.2872 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3981 0.2867 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3344 0.2741 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2256 0.2765 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2104 0.2768 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1625 0.2799 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0883 0.2778 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0669 0.2791 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0080 0.2954 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.0032 0.2889 sec/batch
# Nearest to however: heart, leads, affluent, memory, gradient, controls, retaining, seventy,
# Nearest to two: redfield, paid, hits, voice, gallons, marque, stories, have,
# Nearest to some: wooden, presents, deep, alcoholic, then, groups, morning, surrounding,
# Nearest to it: paid, exposed, defaults, promotion, income, generates, years, meaning,
# Nearest to to: stays, brush, returned, underdeveloped, dt, typically, psychological, improve,
# Nearest to more: often, diet, charts, n, shilling, long, anybody, quiescent,
# Nearest to nine: u, verification, herb, encyclopedists, abilities, neoclassical, norton, elmira,
# Nearest to not: above, twelve, pterosaurs, instructions, distribute, bengals, atrocities, conform,
# Nearest to shows: calendars, talvela, chinook, approves, writing, drainage, passively, fleischmann,
# Nearest to primarily: scratch, predominantly, fragments, nephite, charlestown, all, plane, voluntary,
# Nearest to troops: fatalities, valid, strongest, smarta, soundly, integrated, trainspotting, assists,
# Nearest to something: hour, starting, opposite, gordian, export, vietnamese, lpu, force,
# Nearest to freedom: grade, footwear, hamburger, incomplete, traumatic, tiles, iraqis, sat,
# Nearest to centre: suspects, guides, obtuse, catnip, legitimized, metamorphosis, army, longwood,
# Nearest to versions: tailored, ahmet, hermit, eszterh, durum, pioneering, honest, activity,
# Nearest to operations: humps, eight, motocross, technik, sheng, directory, podcasting, permanent,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9359 0.2935 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9050 0.2999 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8890 0.2844 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8626 0.2914 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.7915 0.2909 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8335 0.2769 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8136 0.2916 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7986 0.2886 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7799 0.2960 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7846 0.2790 sec/batch
# Nearest to however: heart, affluent, leads, gradient, controls, hammadi, sexist, buddhist,
# Nearest to two: redfield, hits, voice, paid, marque, rico, carlisle, keynes,
# Nearest to some: sectioned, wooden, presents, alcoholic, morning, surrounding, belgian, regard,
# Nearest to it: defaults, exposed, paid, colonization, exceeding, promotion, grasping, income,
# Nearest to to: brush, stays, loud, underdeveloped, dt, returned, archetype, brien,
# Nearest to more: diet, charts, anybody, often, quiescent, shilling, gpl, infantryman,
# Nearest to nine: u, herb, lb, auguste, sir, zero, elmira, neoclassical,
# Nearest to not: twelve, distribute, instructions, atrocities, inhibitors, mukti, above, convenient,
# Nearest to shows: calendars, writing, drainage, approves, chinook, passively, talvela, climatic,
# Nearest to primarily: scratch, abiotic, fragments, predominantly, tactics, nephite, charlestown, ghost,
# Nearest to troops: fatalities, crisis, strongest, soundly, smarta, epsilon, valid, assists,
# Nearest to something: hour, opposite, gordian, vietnamese, starting, export, lpu, everywhere,
# Nearest to freedom: grade, footwear, traumatic, iraqis, hamburger, incomplete, tiles, global,
# Nearest to centre: suspects, obtuse, guides, metamorphosis, legitimized, longwood, gpo, catnip,
# Nearest to versions: ahmet, tailored, torvalds, hermit, durum, pioneering, eszterh, originality,
# Nearest to operations: humps, motocross, directory, fa, matured, eight, appliance, technik,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7827 0.2909 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7460 0.2969 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7205 0.3122 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7192 0.2761 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7515 0.2960 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6840 0.2953 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6896 0.3013 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7304 0.2750 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7199 0.2731 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6443 0.2743 sec/batch
# Nearest to however: heart, affluent, hammadi, leads, gradient, buddhist, controls, resistors,
# Nearest to two: redfield, rico, actor, marque, voice, hits, keynes, fantastical,
# Nearest to some: sectioned, alcoholic, leach, wooden, nus, flashes, eller, comparisons,
# Nearest to it: defaults, exposed, paid, partido, theology, colonization, grasping, exceeding,
# Nearest to to: brien, brush, assorted, loud, underdeveloped, stays, irgun, classroom,
# Nearest to more: anybody, diet, quiescent, charts, often, bosses, gpl, shilling,
# Nearest to nine: u, zero, sir, auguste, three, american, herb, six,
# Nearest to not: inhibitors, distribute, turbine, playfair, twelve, aisles, instructions, rang,
# Nearest to shows: drainage, calendars, chinook, approves, writing, passively, talvela, climatic,
# Nearest to primarily: scratch, abiotic, charlestown, fragments, sabotage, nephite, percentages, fraud,
# Nearest to troops: fatalities, crisis, smarta, soundly, regional, strongest, assists, rerun,
# Nearest to something: hour, gordian, opposite, crean, starting, toxicity, lpu, faire,
# Nearest to freedom: footwear, traumatic, iraqis, grade, radclyffe, tiles, hamburger, legge,
# Nearest to centre: suspects, gpo, metamorphosis, longwood, obtuse, worshipper, dowland, marginalize,
# Nearest to versions: ahmet, torvalds, tailored, durum, hermit, pioneering, ningbo, cfr,
# Nearest to operations: humps, fa, motocross, gehrig, appliance, sheng, directory, matured,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6589 0.2784 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6711 0.2771 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6257 0.2848 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6083 0.2815 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6096 0.2758 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6321 0.2746 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6114 0.2002 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5418 0.2741 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5054 0.2747 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5092 0.2748 sec/batch
# Nearest to however: heart, affluent, leads, gradient, buddhist, resistors, hammadi, birdlife,
# Nearest to two: redfield, actor, rico, hits, zero, est, von, marque,
# Nearest to some: sectioned, wooden, regard, leach, foresaw, alcoholic, flashes, nus,
# Nearest to it: defaults, exposed, paid, colonization, partido, wove, cleanse, kel,
# Nearest to to: loud, assorted, had, underdeveloped, brush, classroom, brien, irgun,
# Nearest to more: anybody, diet, quiescent, infantryman, gpl, often, philistia, megara,
# Nearest to nine: american, zero, sir, musician, composer, three, six, u,
# Nearest to not: inhibitors, instructions, thereby, calculating, grease, playfair, aisles, distribute,
# Nearest to shows: drainage, chinook, passively, calendars, writing, talvela, approves, locust,
# Nearest to primarily: abiotic, scratch, charlestown, barbuda, fraud, garbled, tactics, arjuna,
# Nearest to troops: fatalities, crisis, smarta, soundly, majuscule, regional, east, strongest,
# Nearest to something: gordian, crean, opposite, hour, lpu, subscripts, counterfactual, toxicity,
# Nearest to freedom: footwear, traumatic, iraqis, radclyffe, grade, tiles, legge, pontchartrain,
# Nearest to centre: catnip, alm, gpo, longwood, worshipper, elm, obtuse, rio,
# Nearest to versions: ahmet, torvalds, cfr, ningbo, tailored, jive, durum, cartography,
# Nearest to operations: humps, appliance, fa, hogs, gehrig, sheng, motocross, permanent,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4829 0.2755 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4960 0.2744 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4690 0.2740 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5145 0.2739 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4797 0.2748 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4581 0.2733 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4811 0.2749 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4061 0.2777 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4246 0.2742 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4362 0.2735 sec/batch
# Nearest to however: heart, leads, affluent, resistors, gradient, birdlife, russel, buddhist,
# Nearest to two: est, zero, hydro, rico, hits, four, redfield, three,
# Nearest to some: sectioned, regard, nus, foresaw, alcoholic, wooden, leach, argued,
# Nearest to it: defaults, wove, paid, partido, exceeding, grasping, colonization, exposed,
# Nearest to to: had, assorted, improve, brush, underdeveloped, loud, stays, classroom,
# Nearest to more: quiescent, anybody, infantryman, philistia, diet, gpl, tripod, megara,
# Nearest to nine: zero, sir, u, norton, three, pournelle, six, ets,
# Nearest to not: inhibitors, distribute, thereby, grease, instructions, turbine, rang, egalitarian,
# Nearest to shows: chinook, drainage, passively, calendars, writing, talvela, locust, retractable,
# Nearest to primarily: abiotic, scratch, garbled, tactics, athenaeus, shale, fraud, charlestown,
# Nearest to troops: fatalities, crisis, smarta, war, majuscule, soundly, newly, ravaging,
# Nearest to something: opposite, crean, gordian, counterfactual, lpu, hour, toxicity, this,
# Nearest to freedom: footwear, traumatic, iraqis, radclyffe, tiles, pontchartrain, grade, legge,
# Nearest to centre: alm, catnip, rio, sandstone, longwood, gpo, marginalize, ecmascript,
# Nearest to versions: cfr, torvalds, ahmet, jive, ningbo, tailored, cartography, microcontrollers,
# Nearest to operations: appliance, hogs, humps, biotechnology, fa, permanent, navies, sheng,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4514 0.2753 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4064 0.2743 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4701 0.2742 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3994 0.2736 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4250 0.2742 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4408 0.2742 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3892 0.2742 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.4045 0.2736 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4364 0.2739 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3734 0.2743 sec/batch
# Nearest to however: heart, leads, prepositional, affluent, birdlife, gradient, may, sexist,
# Nearest to two: zero, est, four, three, r, redfield, hydro, hits,
# Nearest to some: sectioned, foresaw, regard, nus, wooden, have, leach, argued,
# Nearest to it: defaults, cleanse, grasping, wove, rollout, partido, exceeding, exposed,
# Nearest to to: had, assorted, stays, improve, things, loud, agreed, brush,
# Nearest to more: quiescent, anybody, diet, infantryman, philistia, megara, tripod, gpl,
# Nearest to nine: zero, sir, norton, three, auguste, coleman, herb, ilya,
# Nearest to not: inhibitors, thereby, egalitarian, all, this, grease, seleucids, above,
# Nearest to shows: drainage, chinook, passively, calendars, talvela, approximation, writing, retractable,
# Nearest to primarily: abiotic, scratch, tactics, shale, athenaeus, garbled, conditionals, charlestown,
# Nearest to troops: fatalities, crisis, war, smarta, majuscule, soundly, negotiations, refugees,
# Nearest to something: opposite, crean, gordian, subscripts, counterfactual, lpu, me, starting,
# Nearest to freedom: footwear, traumatic, iraqis, radclyffe, pontchartrain, legge, tiles, sector,
# Nearest to centre: sandstone, alm, rio, catnip, residents, gpo, marginalize, chinaman,
# Nearest to versions: torvalds, ahmet, cfr, microcontrollers, jive, tailored, cartography, ningbo,
# Nearest to operations: appliance, biotechnology, hogs, trigeminal, humps, navies, sheng, decompose,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3808 0.2756 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3978 0.2741 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3851 0.2743 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3491 0.2738 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4117 0.2744 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3750 0.2748 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3804 0.2763 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3723 0.2733 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3562 0.2746 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3316 0.2730 sec/batch
# Nearest to however: heart, prepositional, leads, affluent, birdlife, buddhist, may, retaining,
# Nearest to two: zero, four, three, est, five, six, turnover, eight,
# Nearest to some: sectioned, regard, foresaw, have, argued, nus, leach, regimes,
# Nearest to it: defaults, grasping, wove, cleanse, exceeding, kel, exposed, paid,
# Nearest to to: had, improve, agreed, things, reemerged, stays, gouverneur, loud,
# Nearest to more: quiescent, diet, philistia, anybody, infantryman, megara, efficiency, drago,
# Nearest to nine: zero, three, six, sir, norton, na, pournelle, ets,
# Nearest to not: inhibitors, egalitarian, thereby, grease, canine, seleucids, all, conform,
# Nearest to shows: writing, retractable, locust, chinook, calendars, heliocentric, mencken, talvela,
# Nearest to primarily: abiotic, scratch, shale, tactics, predominantly, mandate, athenaeus, schwarzenberg,
# Nearest to troops: fatalities, crisis, war, smarta, fled, newly, negotiations, ravaging,
# Nearest to something: crean, opposite, me, gordian, subscripts, counterfactual, writing, lpu,
# Nearest to freedom: traumatic, footwear, radclyffe, iraqis, pontchartrain, legge, tiles, forfeiture,
# Nearest to centre: rio, sandstone, alm, catnip, longwood, gpo, residents, chinaman,
# Nearest to versions: torvalds, microcontrollers, ahmet, cfr, jive, cartography, ningbo, pioneering,
# Nearest to operations: biotechnology, hogs, appliance, trigeminal, navies, fabricating, prefectural, humps,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3453 0.2758 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2631 0.2744 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3712 0.2741 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3776 0.2745 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3867 0.2734 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2769 0.2738 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3150 0.2731 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3321 0.2742 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2160 0.2956 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3004 0.2830 sec/batch
# Nearest to however: heart, prepositional, retaining, buddhist, affluent, leads, ordinary, birdlife,
# Nearest to two: zero, four, three, five, est, six, seven, eight,
# Nearest to some: sectioned, foresaw, regard, regimes, have, leach, manmade, processes,
# Nearest to it: defaults, grasping, exceeding, wove, paid, rollout, partido, cleanse,
# Nearest to to: had, agreed, things, stays, reemerged, improve, solution, loud,
# Nearest to more: quiescent, diet, infantryman, philistia, anybody, evangelicals, tripod, megara,
# Nearest to nine: zero, three, six, one, sir, na, norton, auguste,
# Nearest to not: inhibitors, egalitarian, seleucids, all, thereby, wellington, this, conform,
# Nearest to shows: retractable, calendars, writing, locust, rap, approximation, mencken, real,
# Nearest to primarily: abiotic, scratch, tactics, shale, predominantly, firms, schwarzenberg, fraud,
# Nearest to troops: fatalities, crisis, war, smarta, newly, fled, after, negotiations,
# Nearest to something: crean, me, opposite, gordian, counterfactual, subscripts, starting, lpu,
# Nearest to freedom: traumatic, footwear, iraqis, radclyffe, pontchartrain, forfeiture, legge, barratry,
# Nearest to centre: sandstone, rio, alm, catnip, longwood, gpo, residents, rdf,
# Nearest to versions: torvalds, microcontrollers, ahmet, cfr, jive, pioneering, cartography, interfaces,
# Nearest to operations: biotechnology, navies, appliance, trigeminal, hogs, fabricating, kilowatts, prefectural,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3318 0.3006 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2905 0.2941 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3367 0.1325 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2774 0.2850 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2268 0.2857 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.1907 0.3026 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2221 0.2775 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2117 0.2733 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2053 0.3084 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1781 0.3036 sec/batch
# Nearest to however: heart, prepositional, leads, retaining, may, ordinary, resistors, affluent,
# Nearest to two: zero, four, three, five, est, six, eight, seven,
# Nearest to some: foresaw, sectioned, have, regard, regimes, processes, nus, multicolored,
# Nearest to it: defaults, exceeding, grasping, paid, wove, rollout, partido, prefixes,
# Nearest to to: had, things, stays, agreed, solution, reemerged, loud, ltte,
# Nearest to more: quiescent, infantryman, diet, philistia, sharia, evangelicals, tripod, anybody,
# Nearest to nine: zero, three, six, na, one, sir, pournelle, ilya,
# Nearest to not: inhibitors, all, thereby, wellington, seleucids, egalitarian, eigenvector, this,
# Nearest to shows: retractable, calendars, mencken, writing, locust, approximation, rap, chinook,
# Nearest to primarily: abiotic, scratch, tactics, predominantly, shale, phosphorus, charlestown, schwarzenberg,
# Nearest to troops: fatalities, crisis, war, newly, smarta, ravaging, soundly, fled,
# Nearest to something: me, crean, opposite, counterfactual, subscripts, whatever, starting, gordian,
# Nearest to freedom: traumatic, footwear, radclyffe, iraqis, legge, pontchartrain, forfeiture, barratry,
# Nearest to centre: rio, sandstone, alm, catnip, residents, gpo, elm, longwood,
# Nearest to versions: torvalds, microcontrollers, pioneering, cfr, ahmet, jive, cartography, copy,
# Nearest to operations: biotechnology, hogs, appliance, trigeminal, navies, contingency, freer, kilowatts,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2464 0.2897 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2044 0.2727 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2428 0.2735 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1139 0.2737 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1756 0.2743 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1847 0.2730 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1780 0.2726 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1955 0.2732 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2115 0.3547 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1817 0.2757 sec/batch
# Nearest to however: heart, retaining, resistors, leads, floors, birdlife, prepositional, colonisation,
# Nearest to two: zero, four, three, five, est, six, eight, seven,
# Nearest to some: have, foresaw, regard, sectioned, most, regimes, multicolored, processes,
# Nearest to it: defaults, grasping, exceeding, disconnected, rollout, prefixes, flotation, if,
# Nearest to to: had, things, stays, agreed, reemerged, lecoq, wasteful, bloating,
# Nearest to more: quiescent, infantryman, philistia, tripod, often, diet, sharia, weierstrass,
# Nearest to nine: zero, na, three, six, one, pournelle, ets, massoud,
# Nearest to not: all, inhibitors, this, identifying, seleucids, thereby, conform, eigenvector,
# Nearest to shows: retractable, approximation, calendars, writing, real, chinook, mencken, locust,
# Nearest to primarily: abiotic, scratch, tactics, predominantly, shale, charlestown, contributed, fluctuation,
# Nearest to troops: fatalities, crisis, war, newly, smarta, armies, ravaging, negotiations,
# Nearest to something: crean, counterfactual, opposite, subscripts, me, whatever, starting, lpu,
# Nearest to freedom: traumatic, footwear, iraqis, pontchartrain, barratry, legge, radclyffe, forfeiture,
# Nearest to centre: rio, sandstone, alm, catnip, residents, gpo, rail, elm,
# Nearest to versions: torvalds, microcontrollers, pioneering, ahmet, cfr, jive, integrator, indexing,
# Nearest to operations: biotechnology, navies, trigeminal, appliance, fabricating, humps, hogs, kilowatts,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1698 0.2745 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2015 0.2735 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1622 0.2734 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1506 0.2738 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.2076 0.2731 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1983 0.2738 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2037 0.2737 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1654 0.2731 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1362 0.2738 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1921 0.2732 sec/batch
# Nearest to however: retaining, heart, prepositional, leads, colonisation, resistors, floors, affluent,
# Nearest to two: zero, four, five, three, est, six, eight, one,
# Nearest to some: regard, have, foresaw, sectioned, regimes, multicolored, jaya, most,
# Nearest to it: exceeding, defaults, grasping, disconnected, if, back, rollout, prove,
# Nearest to to: had, agreed, stays, things, and, lecoq, wasteful, solution,
# Nearest to more: quiescent, efficiency, infantryman, philistia, sharia, often, evangelicals, wallets,
# Nearest to nine: zero, one, six, three, na, eight, pournelle, seven,
# Nearest to not: all, inhibitors, this, rang, degradation, identifying, windshield, wellington,
# Nearest to shows: mencken, retractable, calendars, locust, rap, mockumentary, real, writing,
# Nearest to primarily: abiotic, predominantly, scratch, tactics, shale, fluctuation, conditionals, charlestown,
# Nearest to troops: fatalities, crisis, armies, smarta, ravaging, fled, war, soundly,
# Nearest to something: crean, opposite, counterfactual, me, whatever, starting, subscripts, lpu,
# Nearest to freedom: footwear, traumatic, forfeiture, barratry, inventing, iraqis, legge, pontchartrain,
# Nearest to centre: rio, sandstone, catnip, alm, residents, gpo, neighbours, longwood,
# Nearest to versions: torvalds, microcontrollers, pioneering, indexing, integrator, ahmet, tailored, jive,
# Nearest to operations: navies, biotechnology, fabricating, trigeminal, bombing, appliance, hogs, kilowatts,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2017 0.2744 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1560 0.2740 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1761 0.2730 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.2005 0.2761 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1273 0.3135 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1374 0.3252 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1545 0.3319 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1353 0.3265 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1763 0.3262 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2195 0.3136 sec/batch
# Nearest to however: retaining, heart, colonisation, triad, affluent, leads, insurrection, resistors,
# Nearest to two: zero, four, five, three, six, eight, est, one,
# Nearest to some: regard, have, sectioned, foresaw, leach, most, regimes, multicolored,
# Nearest to it: exceeding, defaults, grasping, disconnected, exposed, cleanse, prefixes, conspicuously,
# Nearest to to: agreed, had, accusing, ltte, and, reemerged, gouverneur, things,
# Nearest to more: quiescent, evangelicals, infantryman, philistia, elevate, mmix, sharia, efficiency,
# Nearest to nine: one, six, three, zero, eight, na, seven, five,
# Nearest to not: all, seleucids, wellington, inhibitors, tondino, forgive, this, windshield,
# Nearest to shows: mencken, retractable, real, mockumentary, rap, locust, calendars, alda,
# Nearest to primarily: abiotic, predominantly, scratch, tactics, shale, phosphorus, schwarzenberg, contributed,
# Nearest to troops: fatalities, crisis, armies, ravaging, fled, raid, war, newly,
# Nearest to something: crean, me, whatever, skillfully, counterfactual, opposite, spurling, starting,
# Nearest to freedom: footwear, barratry, traumatic, forfeiture, inventing, pontchartrain, living, iraqis,
# Nearest to centre: rio, sandstone, catnip, gpo, alm, residents, neighbours, centres,
# Nearest to versions: torvalds, microcontrollers, ahmet, integrator, hermit, indexing, pioneering, jive,
# Nearest to operations: navies, bombing, biotechnology, kilowatts, fabricating, armored, trigeminal, headquarters,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2215 0.3031 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1238 0.2745 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1312 0.2739 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1537 0.2753 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0314 0.2998 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1807 0.3239 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1475 0.3346 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1255 0.3476 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1697 0.0602 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1133 0.2776 sec/batch
# Nearest to however: retaining, heart, triad, prepositional, resistors, colonisation, leads, floors,
# Nearest to two: zero, four, five, three, six, est, eight, one,
# Nearest to some: have, most, regard, sectioned, foresaw, regimes, jaya, leach,
# Nearest to it: exceeding, defaults, disconnected, grasping, prefixes, exposed, rollout, be,
# Nearest to to: agreed, had, and, underlie, wasteful, stays, reemerged, things,
# Nearest to more: quiescent, philistia, infantryman, often, evangelicals, mmix, efficiency, sharia,
# Nearest to nine: one, zero, three, six, na, eight, seven, pournelle,
# Nearest to not: all, inhibitors, this, tondino, identifying, eigenvector, rang, conform,
# Nearest to shows: mencken, retractable, emmy, real, alda, rap, grime, mockumentary,
# Nearest to primarily: abiotic, predominantly, scratch, shale, contributed, tactics, phosphorus, schwarzenberg,
# Nearest to troops: fatalities, armies, crisis, ravaging, newly, soundly, munitions, fled,
# Nearest to something: crean, me, skillfully, starting, spurling, whatever, lpu, counterfactual,
# Nearest to freedom: footwear, barratry, forfeiture, traumatic, radclyffe, inventing, pontchartrain, legge,
# Nearest to centre: rio, sandstone, gpo, catnip, centres, alm, bleue, neighbours,
# Nearest to versions: torvalds, microcontrollers, indexing, integrator, kde, zilog, tailored, luxuriant,
# Nearest to operations: bombing, navies, kilowatts, fabricating, biotechnology, headquarters, armored, contingency,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0777 0.2804 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0857 0.2772 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0791 0.2775 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0729 0.2735 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0862 0.2741 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0523 0.2738 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0875 0.2735 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0921 0.2734 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1341 0.2800 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0271 0.2747 sec/batch
# Nearest to however: retaining, triad, resistors, colonisation, but, thereafter, ordinary, floors,
# Nearest to two: zero, four, five, three, six, one, eight, est,
# Nearest to some: have, most, regard, leach, foresaw, sectioned, include, routine,
# Nearest to it: exceeding, defaults, disconnected, grasping, prefixes, back, penis, that,
# Nearest to to: had, agreed, and, stays, things, lecoq, solution, reemerged,
# Nearest to more: quiescent, infantryman, often, evangelicals, philistia, mmix, efficiency, wallets,
# Nearest to nine: zero, one, three, six, na, eight, seven, pournelle,
# Nearest to not: all, this, inhibitors, tondino, rang, causality, senussi, wellington,
# Nearest to shows: mencken, real, retractable, emmy, grime, alda, locust, chinook,
# Nearest to primarily: abiotic, scratch, predominantly, tactics, phosphorus, shale, encrypting, contributed,
# Nearest to troops: fatalities, armies, crisis, ravaging, newly, fled, soundly, legions,
# Nearest to something: skillfully, me, whatever, starting, spurling, crean, lpu, counterfactual,
# Nearest to freedom: footwear, barratry, forfeiture, inventing, radclyffe, legge, pontchartrain, traumatic,
# Nearest to centre: rio, sandstone, centres, gpo, catnip, alm, neighbours, bleue,
# Nearest to versions: torvalds, microcontrollers, indexing, integrator, ncsa, zilog, tailored, luxuriant,
# Nearest to operations: bombing, navies, kilowatts, operation, fabricating, armored, humps, biotechnology,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0256 0.2755 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0433 0.2744 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0124 0.2737 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0668 0.2749 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0817 0.2734 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0278 0.2728 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0692 0.2732 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1354 0.2734 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0540 0.2735 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0446 0.2735 sec/batch
# Nearest to however: retaining, resistors, ordinary, attributable, triad, prepositional, leads, but,
# Nearest to two: zero, five, four, three, six, one, eight, est,
# Nearest to some: have, most, regard, include, leach, sectioned, foresaw, multicolored,
# Nearest to it: disconnected, exceeding, grasping, prefixes, that, conspicuously, successions, defaults,
# Nearest to to: and, agreed, had, stays, things, electrics, underlie, lecoq,
# Nearest to more: quiescent, infantryman, evangelicals, philistia, efficiency, often, sharia, wallets,
# Nearest to nine: one, zero, three, six, na, eight, seven, two,
# Nearest to not: all, inhibitors, this, tondino, the, rang, conform, causality,
# Nearest to shows: real, mencken, emmy, locust, chinook, grime, mockumentary, retractable,
# Nearest to primarily: abiotic, scratch, predominantly, tactics, encrypting, shale, contributed, phosphorus,
# Nearest to troops: fatalities, armies, crisis, ravaging, legions, fled, soundly, newly,
# Nearest to something: whatever, starting, skillfully, counterfactual, crean, spurling, subscripts, opposite,
# Nearest to freedom: footwear, forfeiture, inventing, barratry, iraqis, pontchartrain, radclyffe, traumatic,
# Nearest to centre: rio, sandstone, centres, gpo, alm, catnip, bleue, jal,
# Nearest to versions: torvalds, indexing, microcontrollers, integrator, ncsa, luxuriant, pioneering, tailored,
# Nearest to operations: bombing, navies, fabricating, kilowatts, biotechnology, humps, warthog, enforcement,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0333 0.2744 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0739 0.2741 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0762 0.2752 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0389 0.2726 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0556 0.2750 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0618 0.2736 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0825 0.2727 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0558 0.2740 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0625 0.2737 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0734 0.2736 sec/batch
# Nearest to however: retaining, triad, colonisation, mules, but, ordinary, attributable, thereafter,
# Nearest to two: zero, five, four, three, six, one, eight, est,
# Nearest to some: have, regard, most, include, leach, gunships, jaya, manmade,
# Nearest to it: exceeding, disconnected, grasping, prefixes, that, defaults, conspicuously, permitted,
# Nearest to to: agreed, and, had, stays, reemerged, things, returned, servitude,
# Nearest to more: quiescent, infantryman, evangelicals, philistia, sharia, efficiency, groups, often,
# Nearest to nine: one, zero, six, three, eight, na, two, five,
# Nearest to not: all, inhibitors, this, rang, tondino, egalitarian, seleucids, wellington,
# Nearest to shows: emmy, mencken, real, retractable, locust, grime, hammerhead, drainage,
# Nearest to primarily: predominantly, abiotic, tactics, scratch, encrypting, shale, contributed, originating,
# Nearest to troops: fatalities, armies, crisis, legions, ravaging, soundly, fled, newly,
# Nearest to something: skillfully, starting, spurling, whatever, me, prejudice, lpu, counterfactual,
# Nearest to freedom: footwear, inventing, barratry, forfeiture, traumatic, pontchartrain, iraqis, living,
# Nearest to centre: rio, centres, sandstone, gpo, bleue, rdf, alm, neighbours,
# Nearest to versions: torvalds, indexing, fortune, integrator, microcontrollers, ahmet, hermit, ncsa,
# Nearest to operations: bombing, navies, fabricating, kilowatts, armored, plunder, operation, towed,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0564 0.2748 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0168 0.2736 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0339 0.2733 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0520 0.2745 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0840 0.2789 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1084 0.2742 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1122 0.2728 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0338 0.2737 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0434 0.2731 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0592 0.2732 sec/batch
# Nearest to however: retaining, triad, colonisation, ordinary, mules, attributable, thereafter, but,
# Nearest to two: zero, five, four, three, six, eight, one, est,
# Nearest to some: have, most, regard, include, leach, gunships, jaya, sectioned,
# Nearest to it: exceeding, disconnected, prefixes, grasping, that, defaults, conspicuously, bytes,
# Nearest to to: agreed, and, had, stays, sends, electrics, specie, wasteful,
# Nearest to more: quiescent, evangelicals, infantryman, efficiency, philistia, mmix, often, sharia,
# Nearest to nine: one, zero, three, six, two, five, seven, eight,
# Nearest to not: all, this, tondino, inhibitors, rang, wellington, egalitarian, conform,
# Nearest to shows: emmy, real, mencken, grime, drainage, locust, retractable, hammerhead,
# Nearest to primarily: abiotic, tactics, predominantly, scratch, encrypting, contributed, their, sio,
# Nearest to troops: fatalities, armies, crisis, ravaging, legions, newly, soundly, munitions,
# Nearest to something: skillfully, me, starting, whatever, spurling, you, prejudice, counterfactual,
# Nearest to freedom: footwear, barratry, inventing, forfeiture, pontchartrain, traumatic, radclyffe, belief,
# Nearest to centre: centres, rio, sandstone, gpo, bleue, city, rdf, jal,
# Nearest to versions: torvalds, hermit, indexing, fortune, microcontrollers, integrator, ahmet, luxuriant,
# Nearest to operations: bombing, navies, kilowatts, fabricating, enforcement, usaf, contingency, operation,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9797 0.2786 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0182 0.2755 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0369 0.2752 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0362 0.2832 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0619 0.2837 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0290 0.2541 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9983 0.3005 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9959 0.2925 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0061 0.2837 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9666 0.2795 sec/batch
# Nearest to however: retaining, triad, but, ordinary, attributable, hammadi, colonisation, slavic,
# Nearest to two: zero, five, four, three, one, eight, six, seven,
# Nearest to some: have, most, include, regard, leach, gunships, sectioned, foresaw,
# Nearest to it: exceeding, disconnected, that, grasping, prefixes, conspicuously, penis, partido,
# Nearest to to: agreed, and, had, booting, stays, sends, electrics, wasteful,
# Nearest to more: quiescent, infantryman, mmix, evangelicals, often, efficiency, philistia, sharia,
# Nearest to nine: one, zero, three, six, eight, two, seven, five,
# Nearest to not: all, this, tondino, wellington, rang, inhibitors, senussi, eigenvector,
# Nearest to shows: drainage, grime, real, emmy, mencken, locust, shaivism, chinook,
# Nearest to primarily: abiotic, tactics, predominantly, scratch, encrypting, phosphorus, their, contributed,
# Nearest to troops: fatalities, armies, crisis, newly, ravaging, soundly, munitions, legions,
# Nearest to something: skillfully, me, whatever, spurling, starting, prejudice, counterfactual, you,
# Nearest to freedom: footwear, inventing, barratry, forfeiture, pontchartrain, rentenmark, radclyffe, belief,
# Nearest to centre: centres, sandstone, rio, city, gpo, bleue, jal, ferries,
# Nearest to versions: torvalds, indexing, fortune, hermit, kde, luxuriant, integrator, microcontrollers,
# Nearest to operations: bombing, navies, fabricating, kilowatts, plunder, enforcement, usaf, contingency,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0199 0.2799 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9449 0.2783 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0129 0.2753 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0203 0.2794 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0238 0.3167 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9691 0.3148 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9067 0.3105 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9482 0.2957 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9243 0.2821 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9880 0.2898 sec/batch
# Nearest to however: retaining, triad, but, colonisation, mules, ordinary, repayment, acf,
# Nearest to two: zero, five, four, three, one, six, eight, seven,
# Nearest to some: have, most, include, regard, leach, sectioned, persecution, gunships,
# Nearest to it: exceeding, disconnected, that, prefixes, grasping, conspicuously, xx, back,
# Nearest to to: and, had, booting, agreed, electrics, things, stays, a,
# Nearest to more: quiescent, evangelicals, infantryman, philistia, efficiency, groups, often, mmix,
# Nearest to nine: one, zero, three, six, two, seven, eight, five,
# Nearest to not: all, this, the, tondino, defibrillator, senussi, inhibitors, rang,
# Nearest to shows: emmy, real, grime, locust, chinook, drainage, mencken, shaivism,
# Nearest to primarily: abiotic, tactics, predominantly, scratch, encrypting, cities, contributed, originating,
# Nearest to troops: fatalities, armies, crisis, ravaging, newly, legions, munitions, soundly,
# Nearest to something: skillfully, me, whatever, spurling, starting, subscripts, counterfactual, you,
# Nearest to freedom: inventing, barratry, footwear, forfeiture, pontchartrain, radclyffe, rentenmark, shirt,
# Nearest to centre: centres, sandstone, rio, gpo, city, bleue, jal, rdf,
# Nearest to versions: torvalds, luxuriant, fortune, hermit, indexing, kde, sole, zilog,
# Nearest to operations: bombing, operation, kilowatts, navies, fabricating, plunder, usaf, warthog,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9978 0.3063 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0070 0.2998 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9654 0.2769 sec/batch
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-6d252857543a> in <module>
#      18             feed = {inputs: x,
#      19                     labels: np.array(y)[:, None]}
# ---> 20             train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
#      21
#      22             loss += train_loss
#
# ~/anaconda3/envs/tensorflow-cpu/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/tensorflow-cpu/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# ~/anaconda3/envs/tensorflow-cpu/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/anaconda3/envs/tensorflow-cpu/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# ~/anaconda3/envs/tensorflow-cpu/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#    1321     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/anaconda3/envs/tensorflow-cpu/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1405     return tf_session.TF_SessionRun_wrapper(
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#    1409   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
